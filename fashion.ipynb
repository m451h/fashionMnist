# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers

# %%
from tensorflow.keras.datasets import fashion_mnist

# %%
(x_train, y_train),(x_test, y_test) = fashion_mnist.load_data()


x_train = x_train/255
y_train = y_train
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# 40960/29515 [=========================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# 26435584/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 16384/5148 [===============================================================================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step
# 4431872/4422102 [==============================] - 0s 0us/step

# %%
assert x_test.shape == (10000, 28, 28)
y_train.shape
# Out:
# (60000,)

# %%
import matplotlib.pyplot as plt

plt.imshow(x_train[0],cmap='Greys')
print(y_train[0])
# Out:
# 9

# %%
model = tf.keras.models.Sequential(
    [
    layers.Input(x_train.shape[1:]),
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dense(10, activation='softmax')
    ], name= 'model'
)

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 64)                50240
#
#  dense_1 (Dense)             (None, 64)                4160
#
#  dense_2 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 55,050
# Trainable params: 55,050
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x_train, y_train, epochs=50, batch_size=128)
# Out:
# Epoch 1/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0604 - accuracy: 0.9782
# Epoch 2/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0621 - accuracy: 0.9780
# Epoch 3/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0614 - accuracy: 0.9777
# Epoch 4/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0587 - accuracy: 0.9787
# Epoch 5/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0553 - accuracy: 0.9803
# Epoch 6/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0548 - accuracy: 0.9802
# Epoch 7/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0640 - accuracy: 0.9762
# Epoch 8/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0595 - accuracy: 0.9783
# Epoch 9/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0543 - accuracy: 0.9802
# Epoch 10/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0513 - accuracy: 0.9818
# Epoch 11/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0516 - accuracy: 0.9816
# Epoch 12/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0524 - accuracy: 0.9811
# Epoch 13/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0535 - accuracy: 0.9805
# Epoch 14/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0496 - accuracy: 0.9822
# Epoch 15/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0538 - accuracy: 0.9803
# Epoch 16/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0479 - accuracy: 0.9827
# Epoch 17/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0514 - accuracy: 0.9816
# Epoch 18/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0482 - accuracy: 0.9829
# Epoch 19/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0455 - accuracy: 0.9841
# Epoch 20/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0486 - accuracy: 0.9821
# Epoch 21/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0449 - accuracy: 0.9838
# Epoch 22/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0493 - accuracy: 0.9819
# Epoch 23/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0435 - accuracy: 0.9843
# Epoch 24/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0465 - accuracy: 0.9833
# Epoch 25/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0433 - accuracy: 0.9845
# Epoch 26/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0429 - accuracy: 0.9847
# Epoch 27/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0450 - accuracy: 0.9836
# Epoch 28/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0437 - accuracy: 0.9840
# Epoch 29/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0443 - accuracy: 0.9835
# Epoch 30/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0444 - accuracy: 0.9842
# Epoch 31/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0366 - accuracy: 0.9871
# Epoch 32/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0394 - accuracy: 0.9857
# Epoch 33/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0397 - accuracy: 0.9856
# Epoch 34/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0396 - accuracy: 0.9859
# Epoch 35/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0378 - accuracy: 0.9864
# Epoch 36/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0397 - accuracy: 0.9853
# Epoch 37/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0379 - accuracy: 0.9864
# Epoch 38/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0345 - accuracy: 0.9879
# Epoch 39/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0360 - accuracy: 0.9875
# Epoch 40/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0383 - accuracy: 0.9858
# Epoch 41/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0356 - accuracy: 0.9876
# Epoch 42/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0342 - accuracy: 0.9883
# Epoch 43/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0338 - accuracy: 0.9879
# Epoch 44/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0396 - accuracy: 0.9861
# Epoch 45/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0358 - accuracy: 0.9876
# Epoch 46/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0322 - accuracy: 0.9886
# Epoch 47/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0350 - accuracy: 0.9875
# Epoch 48/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0354 - accuracy: 0.9871
# Epoch 49/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0311 - accuracy: 0.9890
# Epoch 50/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0322 - accuracy: 0.9887

# %%
model.evaluate(x_test, y_test)
probs = model.predict(x_test[:40])
preds = np.argmax(probs,axis=1)
for i in range(40):
    plt.imshow(x_test[i], cmap="Greys")
    plt.show()
    if preds[i] == 0:
        print('تیشرت','\n'*4)
    elif preds[i] == 1 :
        print('شلوار','\n'*4)
    elif preds[i] == 2 :
        print('پلیور','\n'*4)
    elif preds[i] == 3 :
        print('پیراهن','\n'*4)
    elif preds[i] == 4 :
        print('کت','\n'*4)
    elif preds[i] == 5 :
        print('صندل','\n'*4)
    elif preds[i] == 6 :
        print('پیراهن','\n'*4)
    elif preds[i] == 7 :
        print('کفش','\n'*4)
    elif preds[i] == 8 :
        print('کیف','\n'*4)
    elif preds[i] == 9 :
        print('بوت','\n'*4)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 207.8225 - accuracy: 0.8642
# بوت
# پلیور
# شلوار
# شلوار
# پیراهن
# شلوار
# کت
# پیراهن
# صندل
# کفش
# کت
# صندل
# کیف
# پیراهن
# کت
# شلوار
# پلیور
# کت
# کیف
# تیشرت
# پلیور
# صندل
# کفش
# صندل
# شلوار
# کت
# کت
# تیشرت
# بوت
# کت
# کیف
# کیف
# پیراهن
# پلیور
# کیف
# تیشرت
# کفش
# صندل
# کفش
# بوت
